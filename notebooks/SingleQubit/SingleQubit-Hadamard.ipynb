# %% [markdown]
# # Single Qubit
# The following code creates a qubit and a classical bit. It then gets the Hadamard applied and finaly measured.
#
# https://medium.com/@harini.hapuarachchi/a-beginners-guide-to-qiskit-1-0-c8e3e854d732

# %%
from qiskit import *

circuit = QuantumCircuit(1, 1)     # circuit with 1 qubit and 1 classical bit

circuit.draw()
#circuit.draw(output="mpl")
circuit.draw(output='latex')
# Out:
# <PIL.Image.Image image mode=RGB size=73x57>

# %%
# subpackages need to be separately imported
from qiskit.quantum_info import Statevector  
from qiskit.visualization import plot_bloch_multivector

init_state = Statevector(circuit);   
print(init_state)  

plot_bloch_multivector(init_state)
# Out:
# Statevector([1.+0.j, 0.+0.j],
#             dims=(2,))

# %%
circuit.h(0);                        # Apply a Hadamard to the q0 of qc
#circuit.draw(output="mpl")
circuit.draw(output='latex')
# Out:
# <PIL.Image.Image image mode=RGB size=122x55>

# %%
h_state = Statevector(circuit); 
print(h_state)  

plot_bloch_multivector(h_state)
# Out:
# Statevector([0.70710678+0.j, 0.70710678+0.j],
#             dims=(2,))

# %%
circuit.measure(0, 0); # Measure qubit 0 to the classical bit 0
#circuit.draw(output="mpl")
circuit.draw(output='latex')
# Out:
# <PIL.Image.Image image mode=RGB size=180x66>

# %%
from qiskit.providers.basic_provider import BasicSimulator
from qiskit.visualization import plot_histogram

backend = BasicSimulator()

# If you do not specify the number of shots, the default is 1024
result = backend.run(circuit, shots=2000).result()   

# Extract the counts of 0 and 1 measurements
counts = result.get_counts()                    
plot_histogram(counts)
