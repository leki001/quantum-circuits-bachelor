# %% [markdown]
# # Tripple Coin Flip
# In the following is a quantum circuit with three qubits that can act as a tripple coin flip.

# %% [markdown]
# ## 1. Import necessary libraries

# %%
from qiskit import QuantumCircuit
from qiskit_aer import AerSimulator
from qiskit import transpile
from qiskit.visualization import plot_distribution

# %% [markdown]
# ## 2. Create the circuit
# 2.1 crate a circuit with three qubit and three classical bit
#
# 2.2 Apply Hadamard gate to the all three qubits (superposition)
#
# 2.3 Measure each qubit and write to corresponding classic bit
#
# (Optional: draw the circuit)

# %%
qc = QuantumCircuit(3, 3)

qc.h(0)
qc.h(1)
qc.h(2)

qc.measure(0, 0)
qc.measure(1, 1)
qc.measure(2, 2)

qc.draw('mpl', initial_state=True)

# %% [markdown]
# ## 3. Simulate the circuit
# 3.1 Select the simulator
#
# 3.2 Transpile the quantum circuit in elementary gates
#
# 3.3 Run the circuit
#
# 3.4 Show the results

# %%
simulator = AerSimulator()

transpile_circuit = transpile(qc, simulator)

result = simulator.run(transpile_circuit, shots=1000).result()

counts = result.get_counts()
probabilities  = {state: (count / sum(counts.values())) * 100 for state, count in counts.items()}

print("Results:     ", counts)
print("Results in %:", probabilities)

plot_distribution(counts, title="Tripple Coin Flip Distribution")
# Out:
# Results:      {'011': 129, '000': 125, '111': 145, '101': 114, '001': 112, '100': 135, '110': 117, '010': 123}
# Results in %: {'011': 12.9, '000': 12.5, '111': 14.499999999999998, '101': 11.4, '001': 11.200000000000001, '100': 13.5, '110': 11.700000000000001, '010': 12.3}
